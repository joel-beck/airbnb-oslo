# %%
from warnings import simplefilter

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

simplefilter(action="ignore", category=FutureWarning)
sns.set_theme(style="whitegrid")
pd.set_option("precision", 3)
pd.set_option("display.max_columns", 100)

# %%
# SECTION: Analyze Performance on Validation Set during Training
classical_models_rfe_results = pd.read_pickle(
    "../results-pickle/classical_models_rfe_results.pkl"
)
neural_network_rfe_results = pd.read_pickle(
    "../results-pickle/neural_network_rfe_results.pkl"
)

complete_rfe_results = pd.concat(
    [
        classical_models_rfe_results,
        neural_network_rfe_results,
    ]
).sort_values("mae_val")

complete_rfe_results.to_pickle("../results-pickle/complete_rfe_results.pkl")

# %%
complete_rfe_results
# Out:
#                                mae_train  mae_val  r2_train  r2_val  \
# Ridge                            371.591  379.976     0.330   0.362
# LinearRegression                 369.768  380.657     0.333   0.361
# HistGradientBoostingRegressor    250.121  382.137     0.764   0.398
# Ridge                            376.573  383.011     0.318   0.355
# HistGradientBoostingRegressor    259.075  383.235     0.740   0.403
# LinearRegression                 376.349  383.456     0.320   0.356
# Ridge                            387.636  392.211     0.302   0.335
# LinearRegression                 386.045  392.397     0.315   0.342
# HistGradientBoostingRegressor    347.008  396.800     0.509   0.358
# RandomForestRegressor            385.401  409.478     0.390   0.331
# RandomForestRegressor            384.866  411.059     0.390   0.324
# Ridge                            405.759  411.145     0.279   0.313
# HistGradientBoostingRegressor    363.033  413.008     0.484   0.343
# LinearRegression                 405.443  413.038     0.290   0.322
# RandomForestRegressor            388.887  414.930     0.391   0.325
# RandomForestRegressor            397.157  425.814     0.384   0.316
# NeuralNetwork                    564.984  447.744     0.193   0.139
# NeuralNetwork                    567.151  456.251     0.205   0.149
# NeuralNetwork                    540.162  456.633     0.171   0.146
# HistGradientBoostingRegressor    457.560  462.432     0.151   0.180
# Ridge                            462.241  462.786     0.153   0.180
# RandomForestRegressor            459.458  466.171     0.171   0.209
# LinearRegression                 466.947  467.674     0.153   0.179
# NeuralNetwork                    553.924  468.480     0.163   0.148
# Ridge                            482.472  482.927     0.126   0.150
# HistGradientBoostingRegressor    482.336  483.857     0.116   0.148
# LinearRegression                 484.362  484.981     0.134   0.155
# RandomForestRegressor            484.682  486.832     0.124   0.161
# NeuralNetwork                    596.211  496.672     0.019   0.082
# NeuralNetwork                    613.461  504.507     0.007   0.089
# Lasso                            568.482  568.715    -0.035  -0.048
# Lasso                            568.482  568.715    -0.035  -0.048
# Lasso                            568.482  568.715    -0.035  -0.048
# Lasso                            568.482  568.715    -0.035  -0.048
# Lasso                            568.482  568.715    -0.035  -0.048
# Lasso                            568.482  568.715    -0.035  -0.048
#
#                                mse_train    mse_val  \
# Ridge                          1.103e+06  1.124e+06
# LinearRegression               1.098e+06  1.123e+06
# HistGradientBoostingRegressor  3.869e+05  1.054e+06
# Ridge                          1.123e+06  1.134e+06
# HistGradientBoostingRegressor  4.262e+05  1.048e+06
# LinearRegression               1.120e+06  1.131e+06
# Ridge                          1.149e+06  1.161e+06
# LinearRegression               1.128e+06  1.144e+06
# HistGradientBoostingRegressor  8.060e+05  1.098e+06
# RandomForestRegressor          1.003e+06  1.180e+06
# RandomForestRegressor          1.002e+06  1.189e+06
# Ridge                          1.187e+06  1.192e+06
# HistGradientBoostingRegressor  8.485e+05  1.086e+06
# LinearRegression               1.169e+06  1.177e+06
# RandomForestRegressor          1.002e+06  1.166e+06
# RandomForestRegressor          1.013e+06  1.176e+06
# NeuralNetwork                  1.201e+06  1.954e+06
# NeuralNetwork                  1.184e+06  1.931e+06
# NeuralNetwork                  1.235e+06  1.940e+06
# HistGradientBoostingRegressor  1.398e+06  1.425e+06
# Ridge                          1.395e+06  1.395e+06
# RandomForestRegressor          1.365e+06  1.384e+06
# LinearRegression               1.393e+06  1.395e+06
# NeuralNetwork                  1.246e+06  1.935e+06
# Ridge                          1.438e+06  1.439e+06
# HistGradientBoostingRegressor  1.455e+06  1.470e+06
# LinearRegression               1.426e+06  1.427e+06
# RandomForestRegressor          1.442e+06  1.450e+06
# NeuralNetwork                  1.460e+06  2.085e+06
# NeuralNetwork                  1.479e+06  2.067e+06
# Lasso                          1.703e+06  1.702e+06
# Lasso                          1.703e+06  1.702e+06
# Lasso                          1.703e+06  1.702e+06
# Lasso                          1.703e+06  1.702e+06
# Lasso                          1.703e+06  1.702e+06
# Lasso                          1.703e+06  1.702e+06
#
#                                                                  hyperparam_keys  \
# Ridge                                                                      alpha
# LinearRegression                                                            None
# HistGradientBoostingRegressor  [min_samples_leaf, max_leaf_nodes, max_iter, m...
# Ridge                                                                      alpha
# HistGradientBoostingRegressor  [min_samples_leaf, max_leaf_nodes, max_iter, m...
# LinearRegression                                                            None
# Ridge                                                                      alpha
# LinearRegression                                                            None
# HistGradientBoostingRegressor  [min_samples_leaf, max_leaf_nodes, max_iter, m...
# RandomForestRegressor                [n_estimators, min_samples_leaf, max_depth]
# RandomForestRegressor                [n_estimators, min_samples_leaf, max_depth]
# Ridge                                                                      alpha
# HistGradientBoostingRegressor  [min_samples_leaf, max_leaf_nodes, max_iter, m...
# LinearRegression                                                            None
# RandomForestRegressor                [n_estimators, min_samples_leaf, max_depth]
# RandomForestRegressor                [n_estimators, min_samples_leaf, max_depth]
# NeuralNetwork                  [batch_size, num_epochs, dropout_probability, ...
# NeuralNetwork                  [batch_size, num_epochs, dropout_probability, ...
# NeuralNetwork                  [batch_size, num_epochs, dropout_probability, ...
# HistGradientBoostingRegressor  [min_samples_leaf, max_leaf_nodes, max_iter, m...
# Ridge                                                                      alpha
# RandomForestRegressor                [n_estimators, min_samples_leaf, max_depth]
# LinearRegression                                                            None
# NeuralNetwork                  [batch_size, num_epochs, dropout_probability, ...
# Ridge                                                                      alpha
# HistGradientBoostingRegressor  [min_samples_leaf, max_leaf_nodes, max_iter, m...
# LinearRegression                                                            None
# RandomForestRegressor                [n_estimators, min_samples_leaf, max_depth]
# NeuralNetwork                  [batch_size, num_epochs, dropout_probability, ...
# NeuralNetwork                  [batch_size, num_epochs, dropout_probability, ...
# Lasso                                                                      alpha
# Lasso                                                                      alpha
# Lasso                                                                      alpha
# Lasso                                                                      alpha
# Lasso                                                                      alpha
# Lasso                                                                      alpha
#
#                                                   hyperparam_values  log_y  \
# Ridge                                                            10   True
# LinearRegression                                               None   True
# HistGradientBoostingRegressor                 [4, 30, 40, 18, 0.09]   True
# Ridge                                                            10   True
# HistGradientBoostingRegressor                 [4, 30, 40, 18, 0.09]   True
# LinearRegression                                               None   True
# Ridge                                                           110   True
# LinearRegression                                               None   True
# HistGradientBoostingRegressor  [6, 15, 40, 24, 0.06999999999999999]   True
# RandomForestRegressor                                     [6, 7, 4]   True
# RandomForestRegressor                                     [6, 7, 4]   True
# Ridge                                                           190   True
# HistGradientBoostingRegressor  [6, 15, 40, 24, 0.06999999999999999]   True
# LinearRegression                                               None   True
# RandomForestRegressor                                     [6, 7, 4]   True
# RandomForestRegressor                                     [6, 7, 4]   True
# NeuralNetwork                        [128, 200, 0.5, 0.01, None, 0]  False
# NeuralNetwork                        [128, 200, 0.5, 0.01, None, 0]  False
# NeuralNetwork                        [128, 200, 0.5, 0.01, None, 0]  False
# HistGradientBoostingRegressor                  [2, 5, 70, 12, 0.03]   True
# Ridge                                                           410   True
# RandomForestRegressor                                     [5, 4, 5]   True
# LinearRegression                                               None   True
# NeuralNetwork                        [128, 200, 0.5, 0.01, None, 0]  False
# Ridge                                                           190   True
# HistGradientBoostingRegressor                  [2, 5, 70, 12, 0.03]   True
# LinearRegression                                               None   True
# RandomForestRegressor                                     [5, 4, 5]   True
# NeuralNetwork                        [128, 200, 0.5, 0.01, None, 0]  False
# NeuralNetwork                        [128, 200, 0.5, 0.01, None, 0]  False
# Lasso                                                            14   True
# Lasso                                                            14   True
# Lasso                                                            14   True
# Lasso                                                            14   True
# Lasso                                                            14   True
# Lasso                                                            14   True
#
#                               feature_selector  num_features  \
# Ridge                                      RFE            50
# LinearRegression                           RFE            50
# HistGradientBoostingRegressor              RFE            50
# Ridge                                      RFE            25
# HistGradientBoostingRegressor              RFE            25
# LinearRegression                           RFE            25
# Ridge                                      RFE            10
# LinearRegression                           RFE            10
# HistGradientBoostingRegressor              RFE            10
# RandomForestRegressor                      RFE            25
# RandomForestRegressor                      RFE            50
# Ridge                                      RFE             5
# HistGradientBoostingRegressor              RFE             5
# LinearRegression                           RFE             5
# RandomForestRegressor                      RFE            10
# RandomForestRegressor                      RFE             5
# NeuralNetwork                              rfe            10
# NeuralNetwork                              rfe            25
# NeuralNetwork                              rfe            50
# HistGradientBoostingRegressor              RFE             2
# Ridge                                      RFE             2
# RandomForestRegressor                      RFE             2
# LinearRegression                           RFE             2
# NeuralNetwork                              rfe             5
# Ridge                                      RFE             1
# HistGradientBoostingRegressor              RFE             1
# LinearRegression                           RFE             1
# RandomForestRegressor                      RFE             1
# NeuralNetwork                              rfe             2
# NeuralNetwork                              rfe             1
# Lasso                                      RFE             5
# Lasso                                      RFE            10
# Lasso                                      RFE             2
# Lasso                                      RFE             1
# Lasso                                      RFE            25
# Lasso                                      RFE            50
#
#                                                                selected_features
# Ridge                          [accommodates, availability_30, bedrooms, cnn_...
# LinearRegression               [accommodates, availability_30, bedrooms, cnn_...
# HistGradientBoostingRegressor  [accommodates, availability_30, bedrooms, cnn_...
# Ridge                          [accommodates, availability_30, bedrooms, cnn_...
# HistGradientBoostingRegressor  [accommodates, availability_30, bedrooms, cnn_...
# LinearRegression               [accommodates, availability_30, bedrooms, cnn_...
# Ridge                          [accommodates, availability_30, bedrooms, cnn_...
# LinearRegression               [accommodates, availability_30, bedrooms, cnn_...
# HistGradientBoostingRegressor  [accommodates, availability_30, bedrooms, cnn_...
# RandomForestRegressor          [accommodates, availability_30, bedrooms, cnn_...
# RandomForestRegressor          [accommodates, availability_30, bedrooms, cnn_...
# Ridge                          [accommodates, availability_30, bedrooms, cnn_...
# HistGradientBoostingRegressor  [accommodates, availability_30, bedrooms, cnn_...
# LinearRegression               [accommodates, availability_30, bedrooms, cnn_...
# RandomForestRegressor          [accommodates, availability_30, bedrooms, cnn_...
# RandomForestRegressor          [accommodates, availability_30, bedrooms, cnn_...
# NeuralNetwork                  [accommodates, availability_30, bedrooms, cnn_...
# NeuralNetwork                  [accommodates, availability_30, bedrooms, cnn_...
# NeuralNetwork                  [accommodates, availability_30, bedrooms, cnn_...
# HistGradientBoostingRegressor                           [accommodates, bedrooms]
# Ridge                                                   [accommodates, bedrooms]
# RandomForestRegressor                                   [accommodates, bedrooms]
# LinearRegression                                        [accommodates, bedrooms]
# NeuralNetwork                  [accommodates, availability_30, bedrooms, cnn_...
# Ridge                                                                 [bedrooms]
# HistGradientBoostingRegressor                                         [bedrooms]
# LinearRegression                                                      [bedrooms]
# RandomForestRegressor                                                 [bedrooms]
# NeuralNetwork                                           [accommodates, bedrooms]
# NeuralNetwork                                                         [bedrooms]
# Lasso                          [accommodates, availability_30, bedrooms, cnn_...
# Lasso                          [accommodates, availability_30, bedrooms, cnn_...
# Lasso                                                   [accommodates, bedrooms]
# Lasso                                                                 [bedrooms]
# Lasso                          [accommodates, availability_30, bedrooms, cnn_...
# Lasso                          [accommodates, availability_30, bedrooms, cnn_...

# %%
plot_data = complete_rfe_results.astype({"num_features": "category"})

# sharex="col", sharey="row" is amazing :)
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(12, 12), sharex="col", sharey=True)
ax1, ax2, ax3, ax4 = axes.flat

sns.scatterplot(
    data=plot_data,
    x="mae_val",
    y=plot_data.index,
    hue="num_features",
    markers=["s", "o"],
    s=70,
    ax=ax1,
).set(title="MAE Validation", xlabel="")

sns.scatterplot(
    data=plot_data,
    x="mae_train",
    y=plot_data.index,
    hue="num_features",
    markers=["s", "o"],
    s=70,
    ax=ax3,
    legend=False,
).set(title="MAE Training", xlabel="")

sns.scatterplot(
    data=plot_data,
    x="r2_val",
    y=plot_data.index,
    hue="num_features",
    markers=["s", "o"],
    s=70,
    ax=ax2,
    legend=False,
).set(title=r"$R^2$ Validation", xlabel="")

sns.scatterplot(
    data=plot_data,
    x="r2_train",
    y=plot_data.index,
    hue="num_features",
    markers=["s", "o"],
    s=70,
    ax=ax4,
    legend=False,
).set(title=r"$R^2$ Training", xlabel="")

fig.suptitle(
    "Model Performances for different feature sets\n"
    "Neural Network fitted with prices on original scale, all other Models fitted with prices on logarithmic scale"
)
fig.subplots_adjust(right=0.8, top=0.9)

sns.move_legend(obj=ax1, loc="center", bbox_to_anchor=(2.5, -0.1), frameon=False)

plt.show()
