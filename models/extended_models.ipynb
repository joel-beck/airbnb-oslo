# %%
from warnings import simplefilter

import numpy as np
import pandas as pd
from sklearn.compose import TransformedTargetRegressor
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.pipeline import make_pipeline
from sklearn.svm import SVR

from sklearn_helpers import (
    ResultContainer,
    fit_models,
    get_column_transformer,
    get_models,
    get_preprocessor,
    show_coefficients,
)

simplefilter(action="ignore", category=FutureWarning)
pd.set_option("precision", 3)
pd.set_option('display.max_columns', 100)

# %%
# NOTE: For Experimentation we train model on the entire data set without splitting in training and test set
listings_extended = pd.read_pickle("../data-clean/listings_extended.pkl")
X = listings_extended.drop(columns="price")
y = listings_extended["price"]

X.shape
# Out:
# (2958, 38)

# %%
# BOOKMARK: Hyperparameters
random_state = 42
n_folds = 10
log_y = True

# 112 total encoded features in listings_extended
# fitting with all 112 features leads to error of evaluating metrics
num_features_list = [10, 25, 50, 75]

# %%
column_transformer = get_column_transformer()

# %%
# SUBSECTION: Analyze Performance for different values of num_features
result_list = []
for num_features in num_features_list:
    if num_features is None:
        preprocessor = column_transformer
    else:
        rfe = RFE(SVR(kernel="linear"), n_features_to_select=num_features, step=0.5)
        preprocessor = get_preprocessor(column_transformer, rfe)
        
    models = get_models(
        preprocessor, models=["linear"], random_state=random_state, log_y=log_y
    )
    result_container = ResultContainer()

    result = fit_models(
        X,
        y,
        models,
        result_container,
        n_folds,
        random_state=random_state,
        log_y=log_y,
    )
    result_list.append(result.display_df())

collected_results = pd.concat(result_list)
# Out:
# Fitting LinearRegression
# Finished training in 40.25 seconds
# Fitting LinearRegression
# Finished training in 41.34 seconds
# Fitting LinearRegression
# Finished training in 40.11 seconds
# Fitting LinearRegression
# Finished training in 29.95 seconds

# %%
collected_results.sort_values("mae_val")
# Out:
#                   mae_train  mae_val  r2_train  r2_val  mse_train    mse_val  \
# LinearRegression    449.992  463.270     0.224   0.181  2.424e+06  2.568e+06
# LinearRegression    447.443  465.330     0.227   0.060  2.416e+06  2.726e+06
# LinearRegression    461.098  471.376     0.224   0.188  2.426e+06  2.560e+06
# LinearRegression    471.616  477.174     0.218   0.225  2.445e+06  2.532e+06
#
#                  hyperparam_keys hyperparam_values  num_features  \
# LinearRegression            None              None            50
# LinearRegression            None              None            75
# LinearRegression            None              None            25
# LinearRegression            None              None            10
#
#                  feature_selector  log_y
# LinearRegression              RFE   True
# LinearRegression              RFE   True
# LinearRegression              RFE   True
# LinearRegression              RFE   True

# %%
# SUBSECTION: Analyze Coefficients for different values of num_features
num_features = 25
rfe = RFE(SVR(kernel="linear"), n_features_to_select=num_features, step=0.5)
preprocessor = get_preprocessor(column_transformer, rfe)
model = LinearRegression()

pipeline = make_pipeline(preprocessor, model)
log_transform = TransformedTargetRegressor(pipeline, func=np.log, inverse_func=np.exp)

log_transform.fit(X, y)
show_coefficients(log_transform)
# Out:
#                                               feature  coefficient
# 0                             property_type_Houseboat        2.506
# 1           property_type_Private room in guest suite        0.982
# 2                              maximum_nights_avg_ntm        0.705
# 3                  property_type_Private room in boat        0.510
# 4                          property_type_Entire villa        0.375
# 5                           room_type_Entire home/apt        0.310
# 6             property_type_Entire serviced apartment        0.241
# 7                                        accommodates        0.201
# 8                              maximum_minimum_nights        0.185
# 9     property_type_Private room in bed and breakfast        0.130
# 10                                           bedrooms        0.127
# 11          property_type_Private room in rental unit       -0.073
# 12  property_type_Private room in condominium (condo)       -0.091
# 13      property_type_Private room in casa particular       -0.093
# 14                                 property_type_Boat       -0.120
# 15           property_type_Shared room in rental unit       -0.133
# 16                             minimum_nights_avg_ntm       -0.183
# 17           neighbourhood_cleansed_Søndre Nordstrand       -0.200
# 18                    neighbourhood_Søndre Nordstrand       -0.200
# 19                   property_type_Entire guest suite       -0.265
# 20                         property_type_Private room       -0.324
# 21                               neighbourhood_Grorud       -0.374
# 22                         property_type_Entire cabin       -0.392
# 23                         property_type_Entire place       -0.559
# 24                             maximum_maximum_nights       -0.716

# %%
X["property_type"].value_counts()
# Out:
# Entire rental unit                     1360
# Entire condominium (condo)              654
# Private room in rental unit             401
# Entire residential home                 123
# Private room in condominium (condo)     101
# Entire townhouse                         67
# Entire loft                              61
# Private room in residential home         41
# Entire villa                             21
# Shared room in rental unit               18
# Private room in loft                     17
# Entire serviced apartment                15
# Private room                             10
# Entire guest suite                        9
# Private room in townhouse                 8
# Private room in villa                     6
# Shared room in condominium (condo)        6
# Entire guesthouse                         6
# Tiny house                                5
# Private room in bed and breakfast         5
# Camper/RV                                 4
# Entire cabin                              4
# Private room in guesthouse                2
# Private room in casa particular           2
# Private room in boat                      2
# Private room in serviced apartment        2
# Houseboat                                 1
# Entire chalet                             1
# Private room in guest suite               1
# Shared room in loft                       1
# Shared room in bed and breakfast          1
# Boat                                      1
# Entire place                              1
# Entire bungalow                           1
# Name: property_type, dtype: Int64

# %%
listings_extended.loc[listings_extended["property_type"] == "Houseboat"]
# Out:
#          neighbourhood        room_type  price  minimum_nights  \
# id
# 24616982       Frogner  Entire home/apt  30000               2
#
#           number_of_reviews  calculated_host_listings_count  availability_365  \
# id
# 24616982                  0                              18               180
#
#           number_of_reviews_ltm host_is_superhost  host_listings_count  \
# id
# 24616982                      0                 f                   20
#
#           host_total_listings_count host_has_profile_pic  \
# id
# 24616982                         20                    t
#
#          host_identity_verified neighbourhood_cleansed property_type  \
# id
# 24616982                      t                Frogner     Houseboat
#
#           accommodates  bedrooms  beds  maximum_nights  \
# id
# 24616982             8         4     6               5
#
#           minimum_minimum_nights  maximum_minimum_nights  \
# id
# 24616982                       2                       2
#
#           minimum_maximum_nights  maximum_maximum_nights  \
# id
# 24616982                       5                       5
#
#           minimum_nights_avg_ntm  maximum_nights_avg_ntm has_availability  \
# id
# 24616982                     2.0                     5.0                t
#
#           availability_30  availability_60  availability_90  \
# id
# 24616982               30               60               90
#
#           number_of_reviews_l30d instant_bookable  \
# id
# 24616982                       0                f
#
#           calculated_host_listings_count_entire_homes  \
# id
# 24616982                                           18
#
#           calculated_host_listings_count_private_rooms  \
# id
# 24616982                                             0
#
#           calculated_host_listings_count_shared_rooms  number_bathrooms  \
# id
# 24616982                                            0               5.0
#
#           shared_bathrooms host_gender  number_amenities  \
# id
# 24616982             False        male                16
#
#           number_front_page_pictures
# id
# 24616982                           5
